# %% [markdown]
# # Project Path

# %% [markdown]
# ## Setup

# %%
# Import packages
import setup
import pandas as pd
from ds_common_utils.aux.io.snowflake_tools import SnowflakeTools

# %%
# Setup analysis and get connection
con = SnowflakeTools().get_snowflake_ctx(
     method = 'token',
    user = '250807',
    role = 'INSIGHT_ANALYST_MERCH_DE_GENERAL_PRD',
    warehouse = 'INSIGHT_ANALYST_WH'
)
setup.set_dates(con, setup.dates)
# Out:
# snowflake_tools - 2025-06-20 18:11:20.935200+10:00 - Generating new token with 'INSIGHT_ANALYST_MERCH_DE_GENERAL_PRD' role and 'SESSION:ROLE-ANY' scope...
# snowflake_tools - 2025-06-20 18:11:26.260401+10:00 - Saved token with '2025-06-20 22:11:26+10:00' expiry...
#    START_DATE    END_DATE PP_START_DATE
# 0  2024-05-01  2025-04-30    2022-10-01

# %% [markdown]
# ## Project Paths

# %%
# Possible granularities for purchase paths
granularity = {
    'dept': {'sub_dept': '-- ', 'class': '-- ', 'sub_class': '-- '}, 
    'sub_dept': {'sub_dept': '', 'class': '-- ', 'sub_class': '-- '}, 
    'class': {'sub_dept': '', 'class': '', 'sub_class': '-- '}, 
    'sub_class': {'sub_dept': '', 'class': '', 'sub_class': ''}
    }

# %%
# Get data at different granularities
consumer_data = {}

for pft_level in granularity:
    # Set parquet path
    parquet_path = 'parquets/df_purchase_path_consumer_AU_pest_control_' + pft_level + '_20_limit.parquet'
    # Get data
    try:
        consumer_data[pft_level] = pd.read_parquet(parquet_path)
    except:
        # Comment out necessary lines in query depending on granularity
        with open('sql/project-path-consumer.sql', 'r') as query:
            pp_query = query.read().format(pp_sub_dept=granularity[pft_level]['sub_dept'], pp_class=granularity[pft_level]['class'], pp_sub_class=granularity[pft_level]['sub_class'])
            df = pd.read_sql_query(pp_query, con)
        consumer_data[pft_level] = df
        df.to_parquet(parquet_path)

# %%
consumer_data
# Out:
# {'dept':                   ITEM_CATEGORY_NAME          ITEM_DEPARTMENT_NAME  \
#  0                 200 HOME DECORATOR                  300 FLOORING
#  1          200 BUILDERS AND PLUMBING        300 BUILDING MATERIALS
#  2                          200 TOOLS              300 TOOL STORAGE
#  3                          200 TOOLS                300 HAND TOOLS
#  4                 200 DESIGN AND ORG                  301 BATHROOM
#  ...                              ...                           ...
#  2513  200 GARDEN MAINT AND CONSTRUCT              300 POWER GARDEN
#  2514                   200 GARDENING              300 PEST CONTROL
#  2515  200 GARDEN MAINT AND CONSTRUCT                  300 WATERING
#  2516              200 OUTDOOR LIVING                 300 FURNITURE
#  2517              200 OUTDOOR LIVING  301 POOL SPA SHEDS AND SHADE
#
#        WEEKS_SINCE_PURCHASE  IRRIGATION_PROJECTS_CONSUMER  CUSTOMERS  \
#  0                      -26                       3449343       3108
#  1                      -26                       3449343        827
#  2                      -26                       3449343        398
#  3                      -26                       3449343       5046
#  4                      -26                       3449343       3145
#  ...                    ...                           ...        ...
#  2513                    26                       3449343       3013
#  2514                    26                       3449343       7308
#  2515                    26                       3449343       9946
#  2516                    26                       3449343       1788
#  2517                    26                       3449343       3863
#
#            SALES  TOTAL_CUSTOMERS  TOTAL_SALES  CUSTOMER_SHARE  SALES_SHARE  \
#  0     197719.54            67881   7372215.77        0.045786     0.000037
#  1      72470.40            67881   7372215.77        0.012183     0.000013
#  2      37608.26            67881   7372215.77        0.005863     0.000007
#  3     142047.96            67881   7372215.77        0.074336     0.000026
#  4     232283.93            67881   7372215.77        0.046331     0.000043
#  ...         ...              ...          ...             ...          ...
#  2513  688960.25           139346  15715728.20        0.021622     0.000127
#  2514  162083.74           139346  15715728.20        0.052445     0.000030
#  2515  351153.32           139346  15715728.20        0.071376     0.000065
#  2516  260714.09           139346  15715728.20        0.012831     0.000048
#  2517  223827.03           139346  15715728.20        0.027722     0.000041
#
#        BASE_CUSTOMER_SHARE  BASE_SALES_SHARE  CUSTOMER_INDEX  SALES_INDEX  \
#  0                0.140720          0.021087        0.325370     0.001735
#  1                0.035779          0.007906        0.340507     0.001696
#  2                0.022871          0.004300        0.256351     0.001618
#  3                0.207742          0.016560        0.357828     0.001587
#  4                0.162903          0.027357        0.284409     0.001571
#  ...                   ...               ...             ...          ...
#  2513             0.100606          0.047849        0.214918     0.002664
#  2514             0.192083          0.011703        0.273033     0.002563
#  2515             0.245073          0.025767        0.291244     0.002522
#  2516             0.069484          0.020015        0.184661     0.002410
#  2517             0.091313          0.017419        0.303593     0.002378
#
#        TOTAL_CUSTOMERS_RANK  SALES_RANK  TOTAL_CUSTOMERS_RAW_RANK  \
#  0                       18           1                        24
#  1                       14           2                        40
#  2                       36           3                        45
#  3                       11           4                        11
#  4                       27           5                        22
#  ...                    ...         ...                       ...
#  2513                    46          44                        37
#  2514                    31          45                        19
#  2515                    26          46                        12
#  2516                    48          47                        41
#  2517                    24          48                        32
#
#        SALES_RAW_RANK
#  0                 12
#  1                 37
#  2                 42
#  3                 25
#  4                  9
#  ...              ...
#  2513               5
#  2514              37
#  2515              18
#  2516              28
#  2517              32
#
#  [2518 rows x 18 columns],
#  'sub_dept':        ITEM_CATEGORY_NAME         ITEM_DEPARTMENT_NAME  \
#  0      200 HOME DECORATOR                 300 SEASONAL
#  1      200 HOME DECORATOR                 300 FLOORING
#  2      200 DESIGN AND ORG   300 KITCHEN AND APPLIANCES
#  3      200 HOME DECORATOR                 300 LIGHTING
#  4      200 OUTDOOR LIVING  300 OUTDOOR HEATING AND REC
#  ...                   ...                          ...
#  19690  200 OUTDOOR LIVING                300 FURNITURE
#  19691          200 TIMBER        300 DOORS AND WINDOWS
#  19692        200 HARDWARE        300 SECURITY HARDWARE
#  19693  200 HOME DECORATOR                 300 SEASONAL
#  19694  200 HOME DECORATOR                 300 SEASONAL
#
#             ITEM_SUB_DEPARTMENT_NAME  WEEKS_SINCE_PURCHASE  \
#  0            402 ELECTRICAL HEATING                   -26
#  1                          403 RUGS                   -26
#  2             401 MODULAR BENCHTOPS                   -26
#  3      402 HOME AUTOMATION PRODUCTS                   -26
#  4               401 OUTDOOR HEATING                   -26
#  ...                             ...                   ...
#  19690         400 FURNITURE LOUNGES                    26
#  19691                    400 SCREEN                    26
#  19692                400 NETWORKING                    26
#  19693        402 ELECTRICAL COOLING                    26
#  19694                  400 HOLIDAYS                    26
#
#         IRRIGATION_PROJECTS_CONSUMER  CUSTOMERS     SALES  TOTAL_CUSTOMERS  \
#  0                           3449343        349  27797.20            67881
#  1                           3449343        266  39274.70            67881
#  2                           3449343         34  19632.88            67881
#  3                           3449343        175  10264.77            67881
#  4                           3449343       1375  62484.05            67881
#  ...                             ...        ...       ...              ...
#  19690                       3449343         91  12930.63           139346
#  19691                       3449343         20   4599.47           139346
#  19692                       3449343        117  18522.50           139346
#  19693                       3449343        590  53458.22           139346
#  19694                       3449343         24    380.64           139346
#
#         TOTAL_SALES  CUSTOMER_SHARE   SALES_SHARE  BASE_CUSTOMER_SHARE  \
#  0       7372215.77        0.005141  5.143290e-06             0.011423
#  1       7372215.77        0.003919  7.266961e-06             0.011430
#  2       7372215.77        0.000501  3.632653e-06             0.001870
#  3       7372215.77        0.002578  1.899281e-06             0.007748
#  4       7372215.77        0.020256  1.156137e-05             0.060004
#  ...            ...             ...           ...                  ...
#  19690  15715728.20        0.000653  2.392542e-06             0.004304
#  19691  15715728.20        0.000144  8.510360e-07             0.000968
#  19692  15715728.20        0.000840  3.427201e-06             0.004064
#  19693  15715728.20        0.004234  9.891325e-06             0.031535
#  19694  15715728.20        0.000172  7.042900e-08             0.001642
#
#         BASE_SALES_SHARE  CUSTOMER_INDEX  SALES_INDEX  TOTAL_CUSTOMERS_RANK  \
#  0              0.001690        0.450057     0.003044                     5
#  1              0.002942        0.342870     0.002470                    12
#  2              0.001482        0.267914     0.002451                    69
#  3              0.000780        0.332731     0.002435                    19
#  4              0.005144        0.337577     0.002247                    15
#  ...                 ...             ...          ...                   ...
#  19690          0.001171        0.151719     0.002044                   372
#  19691          0.000432        0.148760     0.001968                   375
#  19692          0.001742        0.206693     0.001967                   293
#  19693          0.005311        0.134264     0.001862                   378
#  19694          0.000043        0.104750     0.001634                   379
#
#         SALES_RANK  TOTAL_CUSTOMERS_RAW_RANK  SALES_RAW_RANK
#  0               1                       153              76
#  1               2                       177              47
#  2               3                       289             124
#  3               4                       211             215
#  4               5                        35              19
#  ...           ...                       ...             ...
#  19690         375                       308             274
#  19691         376                       340             350
#  19692         377                       302             237
#  19693         378                       186              87
#  19694         379                       337             378
#
#  [19695 rows x 19 columns],
#  'class':               ITEM_CATEGORY_NAME         ITEM_DEPARTMENT_NAME  \
#  0                   200 HARDWARE                  300 FIXINGS
#  1             200 OUTDOOR LIVING  300 OUTDOOR HEATING AND REC
#  2             200 HOME DECORATOR                 300 SEASONAL
#  3             200 OUTDOOR LIVING  300 OUTDOOR HEATING AND REC
#  4             200 HOME DECORATOR                 300 SEASONAL
#  ...                          ...                          ...
#  70171         200 HOME DECORATOR                 300 SEASONAL
#  70172         200 HOME DECORATOR                 300 LIGHTING
#  70173         200 HOME DECORATOR                 300 SEASONAL
#  70174         200 DESIGN AND ORG   300 KITCHEN AND APPLIANCES
#  70175  200 BUILDERS AND PLUMBING                 300 PLUMBING
#
#           ITEM_SUB_DEPARTMENT_NAME                ITEM_CLASS_NAME  \
#  0                  400 LOOSE NAIL              500 DECKING NAILS
#  1             401 OUTDOOR HEATING     500 OUTDOOR HEATING ACCESS
#  2          402 ELECTRICAL HEATING               502 ROOM HEATERS
#  3      401 OUTDOOR PLAY EQUIPMENT                 501 SWING SETS
#  4          402 ELECTRICAL HEATING            502 RADIANT HEATERS
#  ...                           ...                            ...
#  70171        402 FESTIVE LIGHTING                502 INFLATABLES
#  70172            402 CEILING FANS    502 CEILING FAN ACCESSORIES
#  70173      402 ELECTRICAL COOLING  502 PORTABLE AIR CONDITIONERS
#  70174     402 KITCHEN ACCESSORIES       502 KITCHEN ORGANISATION
#  70175  400 GUTTERING AND SPOUTING        500 COLORBOND GUTTERING
#
#         WEEKS_SINCE_PURCHASE  IRRIGATION_PROJECTS_CONSUMER  CUSTOMERS  \
#  0                       -26                       3449343         23
#  1                       -26                       3449343         27
#  2                       -26                       3449343         93
#  3                       -26                       3449343         22
#  4                       -26                       3449343         45
#  ...                     ...                           ...        ...
#  70171                    26                       3449343         43
#  70172                    26                       3449343         31
#  70173                    26                       3449343         21
#  70174                    26                       3449343         44
#  70175                    26                       3449343         21
#
#            SALES  TOTAL_CUSTOMERS  TOTAL_SALES  CUSTOMER_SHARE   SALES_SHARE  \
#  0        822.24            67881   7372215.77        0.000339  1.521380e-07
#  1       1041.88            67881   7372215.77        0.000398  1.927780e-07
#  2      10995.76            67881   7372215.77        0.001370  2.034535e-06
#  3       6852.98            67881   7372215.77        0.000324  1.268000e-06
#  4       2948.84            67881   7372215.77        0.000663  5.456210e-07
#  ...         ...              ...          ...             ...           ...
#  70171   3671.79           139346  15715728.20        0.000309  6.793880e-07
#  70172    757.05           139346  15715728.20        0.000222  1.400760e-07
#  70173   7957.99           139346  15715728.20        0.000151  1.472459e-06
#  70174    639.05           139346  15715728.20        0.000316  1.182430e-07
#  70175    342.22           139346  15715728.20        0.000151  6.332100e-08
#
#         BASE_CUSTOMER_SHARE  BASE_SALES_SHARE  CUSTOMER_INDEX  SALES_INDEX  \
#  0                 0.000977          0.000040        0.346981     0.003836
#  1                 0.001015          0.000055        0.392118     0.003510
#  2                 0.002884          0.000590        0.475035     0.003449
#  3                 0.001181          0.000370        0.274344     0.003427
#  4                 0.001456          0.000163        0.455357     0.003339
#  ...                    ...               ...             ...          ...
#  70171             0.003382          0.000486        0.091366     0.001399
#  70172             0.001368          0.000103        0.162281     0.001361
#  70173             0.001435          0.001084        0.105226     0.001358
#  70174             0.001930          0.000090        0.163731     0.001314
#  70175             0.000679          0.000050        0.222386     0.001268
#
#         TOTAL_CUSTOMERS_RANK  SALES_RANK  TOTAL_CUSTOMERS_RAW_RANK  \
#  0                        27           1                       412
#  1                        17           2                       408
#  2                         8           3                       343
#  3                       109           4                       413
#  4                        10           5                       390
#  ...                     ...         ...                       ...
#  70171                  1365        1365                       579
#  70172                  1273        1366                       591
#  70173                  1362        1367                       601
#  70174                  1267        1368                       578
#  70175                   618        1369                       601
#
#         SALES_RAW_RANK
#  0                 970
#  1                 928
#  2                 165
#  3                 294
#  4                 599
#  ...               ...
#  70171             862
#  70172            1279
#  70173             522
#  70174            1302
#  70175            1352
#
#  [70176 rows x 20 columns],
#  'sub_class':                     ITEM_CATEGORY_NAME         ITEM_DEPARTMENT_NAME  \
#  0       200 GARDEN MAINT AND CONSTRUCT              300 LANDSCAPING
#  1                   200 OUTDOOR LIVING  300 OUTDOOR HEATING AND REC
#  2                         200 HARDWARE                  300 FIXINGS
#  3                   200 HOME DECORATOR                 300 SEASONAL
#  4                   200 HOME DECORATOR                 300 SEASONAL
#  ...                                ...                          ...
#  140490       200 BUILDERS AND PLUMBING       300 BUILDING MATERIALS
#  140491              200 DESIGN AND ORG      301 GARAGE ORGANISATION
#  140492              200 HOME DECORATOR                 300 SEASONAL
#  140493              200 HOME DECORATOR                 300 SEASONAL
#  140494                   200 GARDENING             300 GARDEN DECOR
#
#              ITEM_SUB_DEPARTMENT_NAME                ITEM_CLASS_NAME  \
#  0                400 PAVER AND BRICK                      500 PAVER
#  1                401 OUTDOOR HEATING       501 OUTDOOR HEATING FUEL
#  2            400 BUILDERS CONNECTORS          500 BUILDING BRACKETS
#  3                 402 INDOOR HEATING        503 INDOOR WOOD HEATERS
#  4             402 ELECTRICAL HEATING               502 ROOM HEATERS
#  ...                              ...                            ...
#  140490    400 FIBRECEMENT AND ACCESS   500 INTERIOR CEMENT SHEETING
#  140491  401 STORAGE TUBS SPECIALISED          501 CHRISTMAS STORAGE
#  140492          402 FESTIVE LIGHTING                502 INFLATABLES
#  140493        402 ELECTRICAL COOLING  502 PORTABLE AIR CONDITIONERS
#  140494            400 FUNCTIONAL POT         500 RECYCLED COMPOSITE
#
#                  ITEM_SUB_CLASS_NAME  WEEKS_SINCE_PURCHASE  \
#  0               600 PORCELAIN PAVER                   -26
#  1              600 ECO HEATING FUEL                   -26
#  2            600 SPECIALTY BRACKETS                   -26
#  3       603 WOOD HEATER ACCESSORIES                   -26
#  4            602 CONVECTION HEATERS                   -26
#  ...                             ...                   ...
#  140490                 600 FLOORING                    26
#  140491        601 CHRISTMAS STORAGE                    26
#  140492              602 INFLATABLES                    26
#  140493    602 PORTABLE AIRCON UNITS                    26
#  140494             600 R AND C BOWL                    26
#
#          IRRIGATION_PROJECTS_CONSUMER  CUSTOMERS     SALES  TOTAL_CUSTOMERS  \
#  0                            3449343         23  17114.79            67881
#  1                            3449343         34   1885.86            67881
#  2                            3449343         29   1901.62            67881
#  3                            3449343         39   2011.28            67881
#  4                            3449343         34   3385.64            67881
#  ...                              ...        ...       ...              ...
#  140490                       3449343         29   2791.36           139346
#  140491                       3449343        121   3483.56           139346
#  140492                       3449343         43   3671.79           139346
#  140493                       3449343         21   7957.99           139346
#  140494                       3449343         22    404.46           139346
#
#          ...  CUSTOMER_SHARE   SALES_SHARE  BASE_CUSTOMER_SHARE  \
#  0       ...        0.000339  3.166734e-06             0.001573
#  1       ...        0.000501  3.489390e-07             0.001048
#  2       ...        0.000427  3.518550e-07             0.002060
#  3       ...        0.000575  3.721450e-07             0.001472
#  4       ...        0.000501  6.264420e-07             0.000953
#  ...     ...             ...           ...                  ...
#  140490  ...        0.000208  5.164830e-07             0.001048
#  140491  ...        0.000868  6.445600e-07             0.008738
#  140492  ...        0.000309  6.793880e-07             0.003382
#  140493  ...        0.000151  1.472459e-06             0.001435
#  140494  ...        0.000158  7.483700e-08             0.001078
#
#          BASE_SALES_SHARE  CUSTOMER_INDEX  SALES_INDEX  TOTAL_CUSTOMERS_RANK  \
#  0               0.000331        0.215512     0.009568                   950
#  1               0.000063        0.478053     0.005496                    19
#  2               0.000075        0.207282     0.004714                  1096
#  3               0.000087        0.390625     0.004286                    41
#  4               0.000157        0.525708     0.003999                     9
#  ...                  ...             ...          ...                   ...
#  140490          0.000340        0.198473     0.001520                  1764
#  140491          0.000459        0.099336     0.001406                  2713
#  140492          0.000486        0.091366     0.001399                  2714
#  140493          0.001084        0.105226     0.001358                  2711
#  140494          0.000058        0.146568     0.001288                  2632
#
#          SALES_RANK  TOTAL_CUSTOMERS_RAW_RANK  SALES_RAW_RANK
#  0                1                       386              42
#  1                2                       375             895
#  2                3                       380             889
#  3                4                       370             845
#  4                5                       375             499
#  ...            ...                       ...             ...
#  140490        2751                       609            1319
#  140491        2752                       517            1128
#  140492        2753                       595            1079
#  140493        2754                       617             480
#  140494        2755                       616            2575
#
#  [140495 rows x 21 columns]}

# %%
# Get data at different granularities
commercial_data = {}

for pft_level in granularity:
    # Set parquet path
    parquet_path = 'parquets/df_purchase_path_commercial_NZ_pest_control_' + pft_level + '_20_limit.parquet'
    # Get data
    try:
        commercial_data[pft_level] = pd.read_parquet(parquet_path)
    except:
        # Comment out necessary lines in query depending on granularity
        with open('sql/project-path-commercial.sql', 'r') as query:
            pp_query = query.read().format(pp_sub_dept=granularity[pft_level]['sub_dept'], pp_class=granularity[pft_level]['class'], pp_sub_class=granularity[pft_level]['sub_class'])
            df = pd.read_sql_query(pp_query, con)
        commercial_data[pft_level] = df
        df.to_parquet(parquet_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/250807/Merch-Insights/NZ pest control & growing media/300 PEST CONTROL/Purchase path/purchase_path.ipynb Cell 8 line 1
#      <a href='vscode-notebook-cell://rstudio.dna.bunnings.com.au/home/250807/Merch-Insights/NZ%20pest%20control%20%26%20growing%20media/300%20PEST%20CONTROL/Purchase%20path/purchase_path.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> with open('sql/project-path-commercial.sql', 'r') as query:
#      <a href='vscode-notebook-cell://rstudio.dna.bunnings.com.au/home/250807/Merch-Insights/NZ%20pest%20control%20%26%20growing%20media/300%20PEST%20CONTROL/Purchase%20path/purchase_path.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>     pp_query = query.read().format(pp_sub_dept=granularity[pft_level]['sub_dept'], pp_class=granularity[pft_level]['class'], pp_sub_class=granularity[pft_level]['sub_class'])
# ---> <a href='vscode-notebook-cell://rstudio.dna.bunnings.com.au/home/250807/Merch-Insights/NZ%20pest%20control%20%26%20growing%20media/300%20PEST%20CONTROL/Purchase%20path/purchase_path.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>     df = pd.read_sql_query(pp_query, con)
#      <a href='vscode-notebook-cell://rstudio.dna.bunnings.com.au/home/250807/Merch-Insights/NZ%20pest%20control%20%26%20growing%20media/300%20PEST%20CONTROL/Purchase%20path/purchase_path.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> commercial_data[pft_level] = df
#      <a href='vscode-notebook-cell://rstudio.dna.bunnings.com.au/home/250807/Merch-Insights/NZ%20pest%20control%20%26%20growing%20media/300%20PEST%20CONTROL/Purchase%20path/purchase_path.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> df.to_parquet(parquet_path)
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/pandas/io/sql.py:526, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     523 assert dtype_backend is not lib.no_default
#     525 with pandasSQL_builder(con) as pandas_sql:
# --> 526     return pandas_sql.read_query(
#     527         sql,
#     528         index_col=index_col,
#     529         params=params,
#     530         coerce_float=coerce_float,
#     531         parse_dates=parse_dates,
#     532         chunksize=chunksize,
#     533         dtype=dtype,
#     534         dtype_backend=dtype_backend,
#     535     )
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/pandas/io/sql.py:2738, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2727 def read_query(
#    2728     self,
#    2729     sql,
#    (...)
#    2736     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737 ) -> DataFrame | Iterator[DataFrame]:
# -> 2738     cursor = self.execute(sql, params)
#    2739     columns = [col_desc[0] for col_desc in cursor.description]
#    2741     if chunksize is not None:
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/pandas/io/sql.py:2674, in SQLiteDatabase.execute(self, sql, params)
#    2672 cur = self.con.cursor()
#    2673 try:
# -> 2674     cur.execute(sql, *args)
#    2675     return cur
#    2676 except Exception as exc:
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/snowflake/connector/cursor.py:1016, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements, _force_qmark_paramstyle, _dataframe_ast)
#    1009     logger.debug(
#    1010         "query was rewritten: org=%s, new=%s",
#    1011         " ".join(line.strip() for line in query.split("\n")),
#    1012         query1,
#    1013     )
#    1014     query = query1
# -> 1016 ret = self._execute_helper(query, **kwargs)
#    1017 self._sfqid = (
#    1018     ret["data"]["queryId"]
#    1019     if "data" in ret and "queryId" in ret["data"]
#    1020     else None
#    1021 )
#    1022 logger.debug(f"sfqid: {self.sfqid}")
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/snowflake/connector/cursor.py:722, in SnowflakeCursor._execute_helper(self, query, timeout, statement_params, binding_params, binding_stage, is_internal, describe_only, _no_results, _is_put_get, _no_retry, dataframe_ast)
#     720 ret: dict[str, Any] = {"data": {}}
#     721 try:
# --> 722     ret = self._connection.cmd_query(
#     723         query,
#     724         self._sequence_counter,
#     725         self._request_id,
#     726         binding_params=binding_params,
#     727         binding_stage=binding_stage,
#     728         is_file_transfer=bool(self._is_file_transfer),
#     729         statement_params=statement_params,
#     730         is_internal=is_internal,
#     731         describe_only=describe_only,
#     732         _no_results=_no_results,
#     733         _no_retry=_no_retry,
#     734         timeout=real_timeout,
#     735         dataframe_ast=dataframe_ast,
#     736     )
#     737 finally:
#     738     try:
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/snowflake/connector/connection.py:1579, in SnowflakeConnection.cmd_query(self, sql, sequence_counter, request_id, binding_params, binding_stage, is_file_transfer, statement_params, is_internal, describe_only, _no_results, _update_current_object, _no_retry, timeout, dataframe_ast)
#    1570     logger.debug(
#    1571         "sql=[%s], sequence_id=[%s], is_file_transfer=[%s]",
#    1572         self._format_query_for_log(data["sqlText"]),
#    1573         data["sequenceId"],
#    1574         is_file_transfer,
#    1575     )
#    1577 url_parameters = {REQUEST_ID: request_id}
# -> 1579 ret = self.rest.request(
#    1580     "/queries/v1/query-request?" + urlencode(url_parameters),
#    1581     data,
#    1582     client=client,
#    1583     _no_results=_no_results,
#    1584     _include_retry_params=True,
#    1585     _no_retry=_no_retry,
#    1586     timeout=timeout,
#    1587 )
#    1589 if ret is None:
#    1590     ret = {"data": {}}
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/snowflake/connector/network.py:511, in SnowflakeRestful.request(self, url, body, method, client, timeout, _no_results, _include_retry_params, _no_retry)
#     509     headers[HTTP_HEADER_SERVICE_NAME] = self._connection.service_name
#     510 if method == "post":
# --> 511     return self._post_request(
#     512         url,
#     513         headers,
#     514         json.dumps(body, cls=SnowflakeRestfulJsonEncoder),
#     515         token=self.token,
#     516         _no_results=_no_results,
#     517         timeout=timeout,
#     518         _include_retry_params=_include_retry_params,
#     519         no_retry=_no_retry,
#     520     )
#     521 else:
#     522     return self._get_request(
#     523         url,
#     524         headers,
#     525         token=self.token,
#     526         timeout=timeout,
#     527     )
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/snowflake/connector/network.py:808, in SnowflakeRestful._post_request(self, url, headers, body, token, timeout, socket_timeout, _no_results, no_retry, _include_retry_params)
#     806 result_url = ret["data"]["getResultUrl"]
#     807 logger.debug("ping pong starting...")
# --> 808 ret = self._get_request(
#     809     result_url,
#     810     headers,
#     811     token=self.token,
#     812     timeout=timeout,
#     813     is_fetch_query_status=bool(
#     814         re.match(r"^/queries/.+/result$", result_url)
#     815     ),
#     816 )
#     817 logger.debug("ret[code] = %s", ret.get("code", "N/A"))
#     818 logger.debug("ping pong done")
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/snowflake/connector/network.py:710, in SnowflakeRestful._get_request(self, url, headers, token, timeout, is_fetch_query_status)
#     707     del headers["Content-Length"]
#     709 full_url = f"{self.server_url}{url}"
# --> 710 ret = self.fetch(
#     711     "get",
#     712     full_url,
#     713     headers,
#     714     timeout=timeout,
#     715     token=token,
#     716     is_fetch_query_status=is_fetch_query_status,
#     717 )
#     718 if ret.get("code") == SESSION_EXPIRED_GS_CODE:
#     719     try:
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/snowflake/connector/network.py:874, in SnowflakeRestful.fetch(self, method, full_url, headers, data, timeout, **kwargs)
#     872 retry_ctx.set_start_time()
#     873 while True:
# --> 874     ret = self._request_exec_wrapper(
#     875         session, method, full_url, headers, data, retry_ctx, **kwargs
#     876     )
#     877     if ret is not None:
#     878         return ret
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/snowflake/connector/network.py:924, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     922 raise_raw_http_failure = kwargs.pop("raise_raw_http_failure", False)
#     923 try:
# --> 924     return_object = self._request_exec(
#     925         session=session,
#     926         method=method,
#     927         full_url=full_url,
#     928         headers=headers,
#     929         data=data,
#     930         token=token,
#     931         raise_raw_http_failure=raise_raw_http_failure,
#     932         **kwargs,
#     933     )
#     934     if return_object is not None:
#     935         return return_object
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/snowflake/connector/network.py:1091, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout, is_okta_authentication, raise_raw_http_failure)
#    1087 download_start_time = get_time_millis()
#    1088 # socket timeout is constant. You should be able to receive
#    1089 # the response within the time. If not, ConnectReadTimeout or
#    1090 # ReadTimeout is raised.
# -> 1091 raw_ret = session.request(
#    1092     method=method,
#    1093     url=full_url,
#    1094     headers=headers,
#    1095     data=input_data,
#    1096     timeout=socket_timeout,
#    1097     verify=True,
#    1098     stream=is_raw_binary,
#    1099     auth=SnowflakeAuth(token),
#    1100 )
#    1101 download_end_time = get_time_millis()
#    1103 try:
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/snowflake/connector/vendored/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/snowflake/connector/vendored/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/snowflake/connector/vendored/requests/adapters.py:485, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     482     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     484 try:
# --> 485     resp = conn.urlopen(
#     486         method=request.method,
#     487         url=url,
#     488         body=request.body,
#     489         headers=request.headers,
#     490         redirect=False,
#     491         assert_same_host=False,
#     492         preload_content=False,
#     493         decode_content=False,
#     494         retries=self.max_retries,
#     495         timeout=timeout,
#     496         chunked=chunked,
#     497     )
#     499 except (ProtocolError, OSError) as err:
#     500     raise ConnectionError(err, request=request)
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File ~/.conda/envs/meiji/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~/.conda/envs/meiji/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/.conda/envs/meiji/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/.conda/envs/meiji/lib/python3.10/socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/snowflake/connector/vendored/urllib3/contrib/pyopenssl.py:330, in WrappedSocket.recv_into(self, *args, **kwargs)
#     328         raise
#     329 except OpenSSL.SSL.WantReadError:
# --> 330     if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     331         raise timeout("The read operation timed out")
#     332     else:
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:145, in wait_for_read(sock, timeout)
#     141 def wait_for_read(sock, timeout=None):
#     142     """Waits for reading to be available on a given socket.
#     143     Returns True if the socket is readable, or False if the timeout expired.
#     144     """
# --> 145     return wait_for_socket(sock, read=True, timeout=timeout)
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:106, in poll_wait_for_socket(sock, read, write, timeout)
#     103         t *= 1000
#     104     return poll_obj.poll(t)
# --> 106 return bool(_retry_on_intr(do_poll, timeout))
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:43, in _retry_on_intr(fn, timeout)
#      42 def _retry_on_intr(fn, timeout):
# ---> 43     return fn(timeout)
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:104, in poll_wait_for_socket.<locals>.do_poll(t)
#     102 if t is not None:
#     103     t *= 1000
# --> 104 return poll_obj.poll(t)
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/snowflake/connector/cursor.py:711, in SnowflakeCursor._execute_helper.<locals>.interrupt_handler(*_)
#     708         except (ValueError, TypeError):
#     709             # ignore failures
#     710             pass
# --> 711 raise KeyboardInterrupt
#
# KeyboardInterrupt:

# %%
with pd.ExcelWriter("consumer_purchase_path_raw_data.xlsx") as writer:
    for df in consumer_data:
        consumer_data[df].to_excel(writer, sheet_name=df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/250807/Merch-Insights/NZ pest control & growing media/300 PEST CONTROL/Purchase path/purchase_path.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell://rstudio.dna.bunnings.com.au/home/250807/Merch-Insights/NZ%20pest%20control%20%26%20growing%20media/300%20PEST%20CONTROL/Purchase%20path/purchase_path.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> with pd.ExcelWriter("consumer_purchase_path_raw_data.xlsx") as writer:
#       <a href='vscode-notebook-cell://rstudio.dna.bunnings.com.au/home/250807/Merch-Insights/NZ%20pest%20control%20%26%20growing%20media/300%20PEST%20CONTROL/Purchase%20path/purchase_path.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     for df in consumer_data:
#       <a href='vscode-notebook-cell://rstudio.dna.bunnings.com.au/home/250807/Merch-Insights/NZ%20pest%20control%20%26%20growing%20media/300%20PEST%20CONTROL/Purchase%20path/purchase_path.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>         consumer_data[df].to_excel(writer, sheet_name=df)
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/pandas/io/excel/_base.py:1353, in ExcelWriter.__exit__(self, exc_type, exc_value, traceback)
#    1347 def __exit__(
#    1348     self,
#    1349     exc_type: type[BaseException] | None,
#    1350     exc_value: BaseException | None,
#    1351     traceback: TracebackType | None,
#    1352 ) -> None:
# -> 1353     self.close()
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/pandas/io/excel/_base.py:1357, in ExcelWriter.close(self)
#    1355 def close(self) -> None:
#    1356     """synonym for save, to make it more file-like"""
# -> 1357     self._save()
#    1358     self._handles.close()
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/pandas/io/excel/_openpyxl.py:110, in OpenpyxlWriter._save(self)
#     106 def _save(self) -> None:
#     107     """
#     108     Save workbook to disk.
#     109     """
# --> 110     self.book.save(self._handles.handle)
#     111     if "r+" in self._mode and not isinstance(self._handles.handle, mmap.mmap):
#     112         # truncate file to the written content
#     113         self._handles.handle.truncate()
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/openpyxl/workbook/workbook.py:386, in Workbook.save(self, filename)
#     384 if self.write_only and not self.worksheets:
#     385     self.create_sheet()
# --> 386 save_workbook(self, filename)
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/openpyxl/writer/excel.py:294, in save_workbook(workbook, filename)
#     292 workbook.properties.modified = datetime.datetime.now(tz=datetime.timezone.utc).replace(tzinfo=None)
#     293 writer = ExcelWriter(workbook, archive)
# --> 294 writer.save()
#     295 return True
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/openpyxl/writer/excel.py:275, in ExcelWriter.save(self)
#     273 def save(self):
#     274     """Write data into the archive."""
# --> 275     self.write_data()
#     276     self._archive.close()
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/openpyxl/writer/excel.py:77, in ExcelWriter.write_data(self)
#      74     custom_override = CustomOverride()
#      75     self.manifest.append(custom_override)
# ---> 77 self._write_worksheets()
#      78 self._write_chartsheets()
#      79 self._write_images()
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/openpyxl/writer/excel.py:215, in ExcelWriter._write_worksheets(self)
#     212 for idx, ws in enumerate(self.workbook.worksheets, 1):
#     214     ws._id = idx
# --> 215     self.write_worksheet(ws)
#     217     if ws._drawing:
#     218         self._write_drawing(ws._drawing)
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/openpyxl/writer/excel.py:200, in ExcelWriter.write_worksheet(self, ws)
#     198 else:
#     199     writer = WorksheetWriter(ws)
# --> 200     writer.write()
#     202 ws._rels = writer._rels
#     203 self._archive.write(writer.out, ws.path[1:])
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/openpyxl/worksheet/_writer.py:359, in WorksheetWriter.write(self)
#     355 """
#     356 High level
#     357 """
#     358 self.write_top()
# --> 359 self.write_rows()
#     360 self.write_tail()
#     361 self.close()
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/openpyxl/worksheet/_writer.py:125, in WorksheetWriter.write_rows(self)
#     123 with xf.element("sheetData"):
#     124     for row_idx, row in self.rows():
# --> 125         self.write_row(xf, row, row_idx)
#     127 self.xf.send(None)
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/openpyxl/worksheet/_writer.py:147, in WorksheetWriter.write_row(self, xf, row, row_idx)
#     141 if (
#     142     cell._value is None
#     143     and not cell.has_style
#     144     and not cell._comment
#     145     ):
#     146     continue
# --> 147 write_cell(xf, self.ws, cell, cell.has_style)
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/openpyxl/cell/_writer.py:86, in etree_write_cell(xf, worksheet, cell, styled)
#      83     if value is not None:
#      84         cell_content.text = safe_string(value)
# ---> 86 xf.write(el)
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/et_xmlfile/xmlfile.py:120, in _IncrementalFileWriter.write(self, arg)
#     118     default_ns_attr_prefix = None
#     119     uri_to_prefix = {}
# --> 120 incremental_tree._serialize_ns_xml(
#     121     self._file,
#     122     arg,
#     123     nsmap_scope=nsmap_scope,
#     124     global_nsmap=self.global_nsmap,
#     125     short_empty_elements=True,
#     126     is_html=self.is_html,
#     127     is_root=is_root,
#     128     uri_to_prefix=uri_to_prefix,
#     129     default_ns_attr_prefix=default_ns_attr_prefix,
#     130 )
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/et_xmlfile/incremental_tree.py:613, in _serialize_ns_xml(write, elem, nsmap_scope, global_nsmap, short_empty_elements, is_html, is_root, uri_to_prefix, default_ns_attr_prefix, new_nsmap, **kwargs)
#     566 def _serialize_ns_xml(
#     567     write,
#     568     elem,
#    (...)
#     577     **kwargs,
#     578 ):
#     579     """Serialize an element or tree using 'write' for output.
#     580
#     581     Args:
#    (...)
#     605             New prefix -> uri mapping to be applied to this element.
#     606     """
#     607     (
#     608         tag,
#     609         nsmap_scope,
#     610         default_ns_attr_prefix,
#     611         uri_to_prefix,
#     612         next_remains_root,
# --> 613     ) = write_elem_start(
#     614         write,
#     615         elem,
#     616         nsmap_scope,
#     617         global_nsmap,
#     618         short_empty_elements,
#     619         is_html,
#     620         is_root,
#     621         uri_to_prefix,
#     622         default_ns_attr_prefix,
#     623         new_nsmap=new_nsmap,
#     624     )
#     625     for e in elem:
#     626         _serialize_ns_xml(
#     627             write,
#     628             e,
#    (...)
#     636             new_nsmap=None,
#     637         )
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/et_xmlfile/incremental_tree.py:539, in write_elem_start(write, elem, nsmap_scope, global_nsmap, short_empty_elements, is_html, is_root, uri_to_prefix, default_ns_attr_prefix, new_nsmap, **kwargs)
#     537         write("".join([f' {k}="{ET._escape_attrib_html(v)}"' for k, v in item_parts]))
#     538     else:
# --> 539         write("".join([f' {k}="{ET._escape_attrib(v)}"' for k, v in item_parts]))
#     540 if is_html:
#     541     write(">")
#
# File ~/.conda/envs/meiji/lib/python3.10/site-packages/et_xmlfile/incremental_tree.py:539, in <listcomp>(.0)
#     537         write("".join([f' {k}="{ET._escape_attrib_html(v)}"' for k, v in item_parts]))
#     538     else:
# --> 539         write("".join([f' {k}="{ET._escape_attrib(v)}"' for k, v in item_parts]))
#     540 if is_html:
#     541     write(">")
#
# File ~/.conda/envs/meiji/lib/python3.10/xml/etree/ElementTree.py:1045, in _escape_attrib(text)
#    1042 def _escape_attrib(text):
#    1043     # escape attribute value
#    1044     try:
# -> 1045         if "&" in text:
#    1046             text = text.replace("&", "&amp;")
#    1047         if "<" in text:
#
# KeyboardInterrupt:

# %%
with pd.ExcelWriter("data/commercial_purchase_path_raw_data.xlsx") as writer:
    for df in commercial_data:
        commercial_data[df].to_excel(writer, sheet_name=df)

# %%
# Pivot results
df_consumer_results = {}
family_tree_levels = ['ITEM_CATEGORY_NAME', 'ITEM_DEPARTMENT_NAME', 'ITEM_SUB_DEPARTMENT_NAME', 'ITEM_CLASS_NAME', 'ITEM_SUB_CLASS_NAME']

for i, pft_level in enumerate(granularity):
    df = consumer_data[pft_level]
    df = df.loc[df['SALES_RANK'] <= 10, :]
    df = df.pivot_table(index=family_tree_levels[:i + 2], columns='WEEKS_SINCE_PURCHASE', values='SALES_RANK')
    df = df.astype('Int64')
    df = df.style.background_gradient(subset=pd.IndexSlice[:, df.columns], cmap='Greens_r')
    df_consumer_results[pft_level] = df

# %%
# Pivot results
df_commercial_results = {}
family_tree_levels = ['ITEM_CATEGORY_NAME', 'ITEM_DEPARTMENT_NAME', 'ITEM_SUB_DEPARTMENT_NAME', 'ITEM_CLASS_NAME', 'ITEM_SUB_CLASS_NAME']

for i, pft_level in enumerate(granularity):
    df = commercial_data[pft_level]
    df = df.loc[df['SALES_RANK'] <= 10, :]
    df = df.pivot_table(index=family_tree_levels[:i + 2], columns='WEEKS_SINCE_PURCHASE', values='SALES_RANK')
    df = df.astype('Int64')
    df = df.style.background_gradient(subset=pd.IndexSlice[:, df.columns], cmap='Greens_r')
    df_commercial_results[pft_level] = df

# %%
# Write results to excel
with pd.ExcelWriter("data/purchase_path_consumer_lighting.xlsx") as writer:
    for df in df_consumer_results:
        df_consumer_results[df].to_excel(writer, sheet_name=df)

# %%
# Write results to excel
with pd.ExcelWriter("data/purchase_path_commercial_lighting.xlsx") as writer:
    for df in df_commercial_results:
        df_commercial_results[df].to_excel(writer, sheet_name=df)
